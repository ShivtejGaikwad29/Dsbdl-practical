# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("iris")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
group_summary = df.groupby('species').agg(['mean',"median","min","max","std"])
print(group_summary)
# Out:
#            sepal_length                            sepal_width              \
#                    mean median  min  max       std        mean median  min
# species
# setosa            5.006    5.0  4.3  5.8  0.352490       3.428    3.4  2.3
# versicolor        5.936    5.9  4.9  7.0  0.516171       2.770    2.8  2.0
# virginica         6.588    6.5  4.9  7.9  0.635880       2.974    3.0  2.2
#
#                           petal_length                            petal_width  \
#             max       std         mean median  min  max       std        mean
# species
# setosa      4.4  0.379064        1.462   1.50  1.0  1.9  0.173664       0.246
# versicolor  3.4  0.313798        4.260   4.35  3.0  5.1  0.469911       1.326
# virginica   3.8  0.322497        5.552   5.55  4.5  6.9  0.551895       2.026
#
#
#            median  min  max       std
# species
# setosa        0.2  0.1  0.6  0.105386
# versicolor    1.3  1.0  1.8  0.197753
# virginica     2.0  1.4  2.5  0.274650

# %%
setosa = df[df['species']=='setosa'].describe()
print(setosa)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
ndf = sns.load_dataset('tips')
ndf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
group_summary_tips = ndf.groupby('sex')[['total_bill','tip','size']].agg(['mean','median','std','min','max'])
print(group_summary_tips)
# Out:
#        total_bill                                     tip                   \
#              mean median       std   min    max      mean median       std
# sex
# Male    20.744076  18.35  9.246469  7.25  50.81  3.089618   3.00  1.489102
# Female  18.056897  16.40  8.009209  3.07  44.30  2.833448   2.75  1.159495
#
#                        size
#         min   max      mean median       std min max
# sex
# Male    1.0  10.0  2.630573    2.0  0.955997   1   6
# Female  1.0   6.5  2.459770    2.0  0.937644   1   6
# C:\Users\hp\AppData\Local\Temp\ipykernel_8308\883390511.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   group_summary_tips = ndf.groupby('sex')[['total_bill','tip','size']].agg(['mean','median','std','min','max'])

# %%
male = ndf[ndf['sex']=='Male'].describe()
print(male)
# Out:
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000

# %%
female = ndf[ndf['sex']=='Female'].describe()
print(female)
# Out:
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=ndf,x='sex',y='tip',palette="Set2")
plt.title("histogram for tips")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8308\2527865023.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ndf,x='sex',y='tip',palette="Set2")
