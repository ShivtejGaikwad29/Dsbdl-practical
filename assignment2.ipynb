# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Academic_data.csv")
df
# Out:
#     sr no  english  math  study hours
# 0       1       80    31            9
# 1       2       70    95           11
# 2       3       45    85           12
# 3       4       65    25            5
# 4       5       20    35            9
# 5       6       85    65           31
# 6       7       89   120           21
# 7       8       78   140           40
# 8       9       14    75           55
# 9      10       36    20           30
# 10     11       35    25           26
# 11     12       95    85           15
# 12     13      100    45           74
# 13     14       85    65           80
# 14     15       80    56           25
# 15     16       40    75           21
# 16     17       70    41           20
# 17     18       60    88            6
# 18     19       50    98           12
# 19     20       30   100           11
# 20     21       15    32            8
# 21     22       89    74            4
# 22     23       90    41            5
# 23     24      120    66            3
# 24     25       56    77            2

# %%
df.head()
# Out:
#    sr no  english  math  study hours
# 0      1       80    31            9
# 1      2       70    95           11
# 2      3       45    85           12
# 3      4       65    25            5
# 4      5       20    35            9

# %%
df.tail()
# Out:
#     sr no  english  math  study hours
# 20     21       15    32            8
# 21     22       89    74            4
# 22     23       90    41            5
# 23     24      120    66            3
# 24     25       56    77            2

# %%
df.describe()
# Out:
#            sr no    english        math  study hours
# count  25.000000   25.00000   25.000000    25.000000
# mean   13.000000   63.88000   66.360000    21.400000
# std     7.359801   28.73198   31.342038    21.007935
# min     1.000000   14.00000   20.000000     2.000000
# 25%     7.000000   40.00000   41.000000     8.000000
# 50%    13.000000   70.00000   66.000000    12.000000
# 75%    19.000000   85.00000   85.000000    26.000000
# max    25.000000  120.00000  140.000000    80.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sr no        25 non-null     int64
#  1   english      25 non-null     int64
#  2   math         25 non-null     int64
#  3   study hours  25 non-null     int64
# dtypes: int64(4)
# memory usage: 932.0 bytes

# %%
df.dtypes
# Out:
# sr no          int64
# english        int64
# math           int64
# study hours    int64
# dtype: object

# %%
plt.figure(figsize=(10,8))
sns.histplot(data=df,x='math',y='study hours',palette="Set2")
plt.title("histogram for math")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_20624\1417010079.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df,x='math',y='study hours',palette="Set2")

# %%
numeric_cols = ['english', 'math', 'study hours']

# IQR outlier detection
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"Outliers in {col}:\n", outliers[[col]])
# Out:
# Outliers in english:
#  Empty DataFrame
# Columns: [english]
# Index: []
# Outliers in math:
#  Empty DataFrame
# Columns: [math]
# Index: []
# Outliers in study hours:
#      study hours
# 8            55
# 12           74
# 13           80
